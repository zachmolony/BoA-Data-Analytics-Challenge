# %%
import pandas as pd
# %matplotlib inline
import toyplot as tp
import numpy as np

# %%
dataimp = pd.read_csv("finaldata.csv")

# %%
data = dataimp.dropna()

# %% [markdown]
# ### Random sample of boroughs in London
#
# Below shows the rate of neurotic disorder and crimes commited in each borough and the rate of any type of neurotic disorder within the same area.
#
# Neurotic disorders include: all phobias, depressive episode, generalised anxiety disorder, mixed anxiety depression, obsessive compulsive disorder, panic disorder.

# %%
data
# Out:
#                       area  neurotic-disorder-rate-per-1000-population  \
# 0           City of London                                       190.6
# 1                   Barnet                                       167.4
# 2                    Brent                                       182.3
# 3                   Camden                                       206.3
# 4                Greenwich                                       189.8
# 5   Hammersmith and Fulham                                       205.7
# 6                   Harrow                                       153.9
# 7               Hillingdon                                       160.1
# 8                  Lambeth                                       209.9
# 9                   Newham                                       190.9
# 10               Redbridge                                       161.6
# 11    Richmond upon Thames                                       166.4
# ...

# %%
data.corr()
# Out:
#                                             neurotic-disorder-rate-per-1000-population  \
# neurotic-disorder-rate-per-1000-population                                    1.000000
# crime-rate                                                                    0.751843
#
#                                             crime-rate
# neurotic-disorder-rate-per-1000-population    0.751843
# crime-rate                                    1.000000

# %% [markdown]
# ### Graph illustrating the corrolation of mental health rate and crime rate

# %%
data.plot.scatter(x="neurotic-disorder-rate-per-1000-population", y="crime-rate")

# %% [markdown]
# ### Corrolation of the graph
#
# There is a 75% corrolation between number of neurotic disorders in an area and the crime rate.

# %%
data["neurotic-disorder-rate-per-1000-population"].corr(data["crime-rate"])
# Out:
# 0.75184257548861821

# %% [markdown]
# ### Average for the City of London
#
# City of London	190.6	17717

# %% [markdown]
# ### Average increace in crime per borough

# %%
datainc = pd.read_csv("table.csv")

# %%
#datainc = datainc.groupby("Borough").agg(sum)
datainc
# Out:
#            Borough  increase in %
# 0         Hackney            13.3
# 1           Camden           12.8
# 2         Richmond           12.3
# 3          Bexely            10.5
# 4       Greenwich             9.8
# 5    Westminister             9.2
# 6       Hillingdon            8.3
# 7           Newham            7.7
# 8   Tower Hamlets             7.7
# 9       Redbridge             7.6
# 10      Islington             7.5

# %%
tp.bars(datainc["increase in %"])
# Out:
# (<toyplot.canvas.Canvas at 0x7faf8e1b7b70>,
# ...
#  <toyplot.mark.BarMagnitudes at 0x7faf8e1b4f60>)
# ...
